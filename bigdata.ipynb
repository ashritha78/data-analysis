# %%
import numpy as np
#generate a large volume of random data
volume_data = np.random.rand(1000000)
print("volume of data:",len(volume_data))
# Out:
# volume of data: 1000000

# %%
import time
#simulate streaming data every second for 10 seconds
for i in range(10):
  velocity_data = np.random.rand()
  print("velocity data point:",velocity_data)
  time.sleep(2)
# Out:
# velocity data point: 0.15247493779350219
# velocity data point: 0.06955426169010148
# velocity data point: 0.9785159308566088
# velocity data point: 0.02907411447232844
# velocity data point: 0.5273772596511337
# velocity data point: 0.5864896822644666
# velocity data point: 0.36275108517176524
# velocity data point: 0.35698633493666265
# velocity data point: 0.6610693197116714
# velocity data point: 0.23354372319566974

# %%
#structured data
structured_data = {'id': 1, 'name': 'john', 'age':30}
print(structured_data)
#semi structured data
semi_structured_data ={'person':{'name': 'alice', 'age':25, 'city': 'new york'}}
#unstructured data
unstructured_data = "this is a sample text document. it can contain any information in free form"
# Out:
# {'id': 1, 'name': 'john', 'age': 30}

# %%
import random
#generate some random data with noise
veracity_data = [random.choice([1,2,3,None]) for _ in range(20)]
print("veracity data:", veracity_data)
# Out:
# veracity data: [1, 3, 1, 1, 3, 3, 3, 2, 1, 1, None, 1, 2, None, 1, 1, 1, 1, None, 2]
